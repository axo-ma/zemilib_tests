# %% [markdown]
# # zc_hello
#
# Component Python environment verification.

# %%
import sys
print("Hello from zc_hello!")
print(f"Python: {sys.executable}")
print(f"Base Python: {sys.base_prefix}")
